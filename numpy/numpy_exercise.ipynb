# %%
import numpy as np

# %%
data = np.array([18,85,78,19,92,88,17,76,95,18,65,70,20,90,85]).reshape(5,3)
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65, 70],
#        [20, 90, 85]])

# %%
data.shape
# Out:
# (5, 3)

# %%
np.mean(data[:,0])
# Out:
# np.float64(18.4)

# %%
data[:,1]
# Out:
# array([85, 92, 76, 65, 90])

# %%
np.max(data[:,2])
# Out:
# np.int64(95)

# %%
bool_index =data[:,1]>90

# %%
data[bool_index]
# Out:
# array([[19, 92, 88]])

# %%
data[:,1] + 5
# Out:
# array([90, 97, 81, 70, 95])

# %%
bool_index = data[:,0]>19

# %%
data[bool_index]
# Out:
# array([[20, 90, 85]])

# %%
np.mean(data,axis =0)
# Out:
# array([18.4, 81.6, 83.2])

# %%
bool_index = data[:,1] & data[:,2] >=80

# %%
data[bool_index]
# Out:
# array([[19, 92, 88],
#        [20, 90, 85]])

# %%
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65, 70],
#        [20, 90, 85]])

# %%
data[(data[:,2])<75] =0
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [ 0,  0,  0],
#        [20, 90, 85]])
